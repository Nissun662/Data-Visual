# %% [markdown]
# <a href="https://colab.research.google.com/github/Nissun662/Data-Visual/blob/main/Quiz13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Processing and Visualization
# ##Nishan Sunar
# 250662

# %% [markdown]
# #Today's assignment:
#
# Using the banks dataset retrieved from UCI Machine Learning Repo but also accessible here. Explore the following questions:
#
# 1. What is the data type of the first column? Should you change it or is that the best data type.
# 2. The second column is job could you assign an order to this string? Could you assign an order the the fourth column education. If yes, what order would you assign? Do so.
# 3. Could any of the columns have been a boolean? Find one and create a new column in the dataframe that is just boolean and has a descriptive name.
# 4. Name one more interesting fact about this dataset and the datatypes.

# %% [markdown]
# Loading libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# On the next step, I am going to import the csv file from Dr. Jacob's repository.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/bank.csv')
df.head()
# Out:
#    age          job  marital  education  ... pdays  previous poutcome   y
# 0   30   unemployed  married    primary  ...    -1         0  unknown  no
# 1   33     services  married  secondary  ...   339         4  failure  no
# 2   35   management   single   tertiary  ...   330         1  failure  no
# 3   30   management  married   tertiary  ...    -1         0  unknown  no
# 4   59  blue-collar  married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %%
df.age.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# As we can see in the above data, the first column is of datatype `int64` which is for integer value so we do not need to change it.

# %% [markdown]
# To answer question number 2, first I am going to see what is the data type in the second column.

# %%
df.job.dtypes
# Out:
# dtype('O')

# %% [markdown]
# The output `O` implies that the datatype in the second column is `object`. Since, the column represents Job type in different categories so it is not necessary to assign a string as it already has one i.e; object.

# %%
print(df["education"])
# Out:
# 0         primary
# 1       secondary
# 2        tertiary
# 3        tertiary
# 4       secondary
#           ...
# 4516    secondary
# 4517     tertiary
# 4518    secondary
# 4519    secondary
# 4520     tertiary
# Name: education, Length: 4521, dtype: object

# %% [markdown]
# Here in the fourth column, the datatype is object. Since, we have been going to primary school first and then the secondary and then the tertiary so yes, we can arrange this column by order. I am going to put them in order in the code section below:

# %%
from pandas.api.types import CategoricalDtype

education_type = CategoricalDtype(categories=['primary', 'secondary', "tertiary"], ordered=True)

df_education = df.education.astype(education_type)
df.head(10)
# Out:
#    age            job  marital  education  ... pdays  previous poutcome   y
# 0   30     unemployed  married    primary  ...    -1         0  unknown  no
# 1   33       services  married  secondary  ...   339         4  failure  no
# 2   35     management   single   tertiary  ...   330         1  failure  no
# 3   30     management  married   tertiary  ...    -1         0  unknown  no
# 4   59    blue-collar  married  secondary  ...    -1         0  unknown  no
# 5   35     management   single   tertiary  ...   176         3  failure  no
# 6   36  self-employed  married   tertiary  ...   330         2    other  no
# 7   39     technician  married  secondary  ...    -1         0  unknown  no
# 8   41   entrepreneur  married   tertiary  ...    -1         0  unknown  no
# 9   43       services  married    primary  ...   147         2  failure  no
#
# [10 rows x 17 columns]

# %% [markdown]
# Yes there are few columns that has boolean. The column named as default, loan, housing and y has the boolean true/false.
#
# I am going to show boolean by selecting the loan column. I am only going to display the people who are not eligible for loan.

# %%
df[df.loan == 'no'].head(20)
# Out:
#     age            job   marital  education  ... pdays  previous poutcome    y
# 0    30     unemployed   married    primary  ...    -1         0  unknown   no
# 2    35     management    single   tertiary  ...   330         1  failure   no
# 4    59    blue-collar   married  secondary  ...    -1         0  unknown   no
# 5    35     management    single   tertiary  ...   176         3  failure   no
# 6    36  self-employed   married   tertiary  ...   330         2    other   no
# 7    39     technician   married  secondary  ...    -1         0  unknown   no
# 8    41   entrepreneur   married   tertiary  ...    -1         0  unknown   no
# 10   39       services   married  secondary  ...    -1         0  unknown   no
# 11   43         admin.   married  secondary  ...    -1         0  unknown   no
# 12   36     technician   married   tertiary  ...    -1         0  unknown   no
# 13   20        student    single  secondary  ...    -1         0  unknown  yes
# ...

# %% [markdown]
# ##Interesting facts:
# I saw that the dataset in todays assignment had boolean. This datatype is only consists of two argument, either it is true or it is false and the assigned values is 1 & 0 only. Also, the dataset had categories and quantities.
